# %%
import numpy as np
import pandas as pd
import os
import shutil
import random
from collections import Counter
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, UnidentifiedImageError
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split

for dirname,_,finenames in os.walk('/kaggle/input'):
    for filename in finenames:
        print(os.path.join(dirname,filename))
# Out:
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/266.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/071.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/344.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/228.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/099.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/130.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/158.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/003.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/253.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/014.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/381.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/263.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/335.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/287.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/265.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/250.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/251.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/399.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/035.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/166.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/252.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/155.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/152.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/348.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/378.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/389.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/462.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/032.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/073.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/238.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/007.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/469.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/037.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/385.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/311.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/023.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/303.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/124.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/283.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/423.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/139.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/365.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/096.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/367.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/352.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/179.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/245.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/362.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/289.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/108.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/060.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/111.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/148.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/197.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/248.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/339.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/277.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/340.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/115.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/249.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/393.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/334.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/170.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/411.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/409.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/104.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/131.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/337.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/194.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/063.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/349.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/059.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/444.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/437.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/436.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/442.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/044.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/144.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/087.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/493.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/282.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/447.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/064.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/196.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/414.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/269.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/006.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/036.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/203.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/102.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/011.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/478.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/354.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/068.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/314.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/254.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/480.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/445.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/156.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/259.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/189.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/175.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/146.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/294.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/126.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/271.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/341.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/494.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/101.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/239.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/058.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/481.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/020.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/050.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/453.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/330.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/359.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/499.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/093.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/204.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/225.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/005.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/428.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/207.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/488.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/016.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/113.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/160.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/465.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/327.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/454.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/490.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/351.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/306.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/030.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/429.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/138.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/010.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/153.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/028.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/288.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/018.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/067.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/404.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/477.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/435.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/172.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/350.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/227.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/396.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/421.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/088.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/304.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/374.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/222.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/483.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/318.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/395.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/118.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/446.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/178.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/246.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/482.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/284.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/184.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/224.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/307.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/363.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/390.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/200.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/213.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/439.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/120.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/426.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/164.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/457.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/319.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/279.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/361.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/119.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/500.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/379.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/243.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/054.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/215.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/473.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/415.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/052.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/084.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/106.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/116.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/066.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/079.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/042.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/407.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/161.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/163.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/004.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/322.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/077.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/470.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/142.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/295.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/256.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/157.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/290.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/132.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/430.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/403.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/331.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/433.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/461.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/466.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/422.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/487.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/241.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/427.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/369.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/472.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/154.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/149.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/323.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/041.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/460.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/190.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/127.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/229.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/183.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/417.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/082.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/296.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/355.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/056.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/450.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/094.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/080.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/008.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/419.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/145.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/353.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/449.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/038.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/356.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/485.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/057.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/186.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/382.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/402.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/272.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/019.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/180.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/475.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/370.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/276.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/089.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/489.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/332.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/188.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/376.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/270.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/408.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/110.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/129.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/021.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/401.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/121.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/027.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/346.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/046.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/467.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/297.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/177.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/137.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/321.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/221.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/074.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/257.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/208.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/231.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/039.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/061.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/372.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/135.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/434.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/273.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/380.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/069.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/373.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/182.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/174.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/392.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/062.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/162.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/217.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/202.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/232.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/176.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/045.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/479.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/226.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/195.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/193.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/033.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/413.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/406.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/122.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/114.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/451.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/320.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/255.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/326.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/386.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/123.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/159.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/299.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/309.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/424.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/100.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/013.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/441.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/328.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/051.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/432.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/103.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/078.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/001.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/388.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/097.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/024.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/206.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/236.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/015.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/342.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/343.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/165.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/375.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/476.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/233.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/292.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/484.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/496.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/366.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/040.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/009.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/459.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/316.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/169.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/034.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/492.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/357.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/150.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/315.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/012.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/308.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/443.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/209.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/456.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/358.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/264.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/301.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/400.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/081.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/471.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/002.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/268.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/095.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/486.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/497.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/383.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/312.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/171.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/310.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/151.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/219.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/072.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/230.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/468.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/117.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/092.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/464.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/055.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/026.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/368.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/043.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/218.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/240.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/495.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/173.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/438.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/086.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/049.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/143.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/448.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/185.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/325.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/498.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/053.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/420.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/025.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/205.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/377.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/412.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/455.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/291.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/398.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/140.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/210.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/214.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/416.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/302.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/022.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/384.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/017.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/134.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/440.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/474.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/278.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/431.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/198.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/410.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/397.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/234.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/098.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/136.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/125.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/274.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/065.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/091.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/300.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/324.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/191.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/105.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/345.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/167.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/076.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/181.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/405.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/147.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/107.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/418.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/223.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/262.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/047.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/333.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/109.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/242.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/391.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/463.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/285.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/244.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/336.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/216.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/128.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/371.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/275.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/212.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/199.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/280.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/360.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/258.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/141.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/491.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/305.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/317.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/168.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/387.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/286.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/281.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/133.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/458.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/220.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/329.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/347.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/192.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/338.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/267.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/235.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/029.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/090.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/211.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/083.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/048.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/112.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/394.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/293.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/298.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/187.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/364.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/247.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/260.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/075.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/452.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/237.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/261.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/031.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/425.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/313.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/070.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/201.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/CANCER/085.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/071.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/228.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/099.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/130.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/158.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/003.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/014.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/250.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/035.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/166.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/155.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/152.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/032.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/073.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/238.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/007.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/037.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/023.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/124.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/139.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/096.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/179.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/245.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/108.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/060.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/111.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/148.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/197.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/248.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/115.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/249.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/170.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/104.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/131.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/194.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/063.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/059.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/044.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/144.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/087.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/064.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/196.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/006.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/036.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/203.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/102.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/011.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/068.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/156.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/189.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/175.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/146.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/126.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/101.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/239.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/058.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/020.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/050.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/093.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/204.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/225.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/005.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/207.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/016.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/113.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/160.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/030.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/138.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/010.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/153.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/028.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/018.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/067.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/172.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/227.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/088.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/222.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/118.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/178.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/246.jpeg
# /kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset/NON CANCER/184.jpeg
# ...
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/051.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/432.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/103.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/078.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/001.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/388.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/097.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/024.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/206.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/236.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/015.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/342.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/343.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/165.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/375.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/233.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/292.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/366.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/040.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/009.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/316.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/169.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/034.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/357.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/150.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/315.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/012.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/308.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/443.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/209.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/358.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/264.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/301.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/400.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/081.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/002.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/268.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/095.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/383.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/312.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/171.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/310.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/151.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/219.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/072.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/230.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/117.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/092.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/055.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/026.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/368.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/043.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/218.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/240.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/173.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/438.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/086.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/049.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/143.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/448.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/185.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/325.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/053.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/420.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/025.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/205.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/377.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/412.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/291.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/398.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/140.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/210.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/214.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/416.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/302.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/022.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/384.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/017.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/134.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/440.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/278.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/431.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/198.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/410.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/397.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/234.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/098.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/136.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/125.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/274.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/065.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/091.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/300.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/324.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/191.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/105.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/345.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/167.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/076.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/181.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/405.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/147.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/107.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/418.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/223.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/262.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/047.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/333.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/109.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/242.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/391.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/285.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/244.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/336.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/216.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/128.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/371.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/275.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/212.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/199.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/280.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/360.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/258.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/141.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/305.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/317.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/168.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/387.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/286.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/281.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/133.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/220.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/329.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/347.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/192.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/338.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/267.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/235.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/029.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/090.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/211.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/083.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/048.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/112.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/394.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/293.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/298.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/187.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/364.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/247.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/260.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/075.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/237.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/261.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/031.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/425.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/313.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/070.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/201.jpeg
# /kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new/NON CANCER/085.jpeg

# %%
dataset1 = "/kaggle/input/oral-cancer-dataset/Oral Cancer/Oral Cancer Dataset"
dataset2 = "/kaggle/input/oral-cancer-dataset/Oral cancer Dataset 2.0/OC Dataset kaggle new"
merged_dataset = "/kaggle/working/merged_oral_cancer_dataset"

os.makedirs(merged_dataset, exist_ok=True)
for cls in ["CANCER", "NON CANCER"]:
    os.makedirs(os.path.join(merged_dataset, cls), exist_ok=True)

def merge_folders(src_folder, dst_folder):
    if not os.path.exists(src_folder):
        print(f"Warning: src_folder not found: {src_folder}")
        return
    for root, _, files in os.walk(src_folder):
        for file in files:
            if not file.lower().endswith((".jpg", ".jpeg", ".png")):
                continue
            src_file = os.path.join(root, file)
            dst_file = os.path.join(dst_folder, file)
            if os.path.exists(dst_file):
                base, ext = os.path.splitext(file)
                i = 1
                while os.path.exists(os.path.join(dst_folder, f"{base}_copy{i}{ext}")):
                    i += 1
                dst_file = os.path.join(dst_folder, f"{base}_copy{i}{ext}")
            shutil.copy(src_file, dst_file)

for cls in ["CANCER", "NON CANCER"]:
    merge_folders(os.path.join(dataset1, cls), os.path.join(merged_dataset, cls))
    merge_folders(os.path.join(dataset2, cls), os.path.join(merged_dataset, cls))

print("Merging complete. Final dataset at:", merged_dataset)
# Out:
# Merging complete. Final dataset at: /kaggle/working/merged_oral_cancer_dataset

# %%
sizes = []
removed_files = []
for cls in ["CANCER", "NON CANCER"]:
    folder = os.path.join(merged_dataset, cls)
    if not os.path.exists(folder):
        continue
    for file in os.listdir(folder):
        if not file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue
        img_path = os.path.join(folder, file)
        try:
            with Image.open(img_path) as im:
                im.verify() 
            with Image.open(img_path) as im2:
                sizes.append(im2.size)
        except (UnidentifiedImageError, OSError) as e:
            print(f"Skipping corrupted file: {img_path} -> {e}")
            try:
                os.remove(img_path)
                removed_files.append(img_path)
            except:
                pass

size_counts = Counter(sizes)
print("Top 10 most common image sizes:")
for size, count in size_counts.most_common(10):
    print(size, ":", count)


print(f"Total corrupted files removed: {len(removed_files)}")
# Out:
# Top 10 most common image sizes:
# (280, 205) : 62
# (960, 1280) : 28
# (275, 183) : 18
# (468, 1040) : 18
# (720, 1280) : 13
# (1800, 4000) : 10
# (1100, 618) : 8
# (1280, 720) : 8
# (4000, 3000) : 8
# (225, 225) : 7
# Total corrupted files removed: 0

# %%
import matplotlib.image as mpimg
classes = ["CANCER", "NON CANCER"]
all_images = []
for cls in classes:
    folder = os.path.join(merged_dataset, cls)
    images = [os.path.join(folder, img) for img in os.listdir(folder) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
    for img_path in images:
        all_images.append((img_path, cls))
        
sample_images = random.sample(all_images, 5)

# Plot them
plt.figure(figsize=(15, 8))
for i, (img_path, cls) in enumerate(sample_images):
    img = mpimg.imread(img_path)
    plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
input_base = merged_dataset
preprocessed_base = "/kaggle/working/preprocessed_oral_cancer_dataset"
os.makedirs(preprocessed_base, exist_ok=True)

for cls in ["CANCER", "NON CANCER"]:
    os.makedirs(os.path.join(preprocessed_base, cls), exist_ok=True)

for cls in ["CANCER", "NON CANCER"]:
    folder = os.path.join(input_base, cls)
    out_folder = os.path.join(preprocessed_base, cls)
    if not os.path.exists(folder):
        continue
    for file in tqdm(os.listdir(folder), desc=f"Preprocessing {cls}"):
        if not file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue
        src = os.path.join(folder, file)
        dst = os.path.join(out_folder, file)
        try:
            img = cv2.imread(src)
            if img is None:
                print("Unreadable:", src)
                continue

            # Resize
            img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_LANCZOS4)

            # Save preprocessed image
            cv2.imwrite(dst, img)
        except Exception as e:
            print("Error processing", src, e)

print("Preprocessing complete.")
# Out:
# Preprocessing CANCER:   7%|▋         | 71/1000 [00:00<00:06, 132.72it/s]libpng warning: iCCP: extra compressed data
# Preprocessing CANCER:  72%|███████▏  | 724/1000 [00:06<00:02, 123.36it/s]libpng warning: iCCP: extra compressed data
# Preprocessing CANCER: 100%|██████████| 1000/1000 [00:09<00:00, 110.40it/s]
# Preprocessing NON CANCER: 100%|██████████| 700/700 [00:09<00:00, 76.69it/s]
# Preprocessing complete.

# %%
all_images = []
for cls in ["CANCER", "NON CANCER"]:
    folder = os.path.join(preprocessed_base, cls)
    all_images += [(os.path.join(folder, f), cls) for f in os.listdir(folder) 
                   if f.lower().endswith((".jpg", ".jpeg", ".png"))]

# Pick 5 random images
random_images = random.sample(all_images, min(5, len(all_images)))

# Display images with labels
plt.figure(figsize=(15,5))
for i, (img_path, label) in enumerate(random_images):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    plt.subplot(1, 5, i+1)
    plt.imshow(img)
    plt.title(f"{label}\n{os.path.basename(img_path)}", fontsize=10)
    plt.axis("off")
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm

def random_contrast(image, lower=0.8, upper=1.2):
    image = tf.image.random_contrast(image, lower=lower, upper=upper)
    image = tf.clip_by_value(image, 0, 255)
    return tf.cast(image, tf.uint8)

preprocessed_folder = preprocessed_base  
aug_folder = "/kaggle/working/augmented_oral_cancer_dataset"
os.makedirs(aug_folder, exist_ok=True)
for cls in ["CANCER", "NON CANCER"]:
    os.makedirs(os.path.join(aug_folder, cls), exist_ok=True)

orig_counts = {
    cls: len([
        f for f in os.listdir(os.path.join(preprocessed_folder, cls))
        if f.lower().endswith((".jpg", ".jpeg", ".png"))
    ])
    for cls in ["CANCER", "NON CANCER"]
}
print("Before Augmentation:")
for cls in orig_counts:
    print(f"  {cls}: {orig_counts[cls]} images")
print(f"  Total: {sum(orig_counts.values())}\n")

datagen = ImageDataGenerator(
    rotation_range=30,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=(0.8, 1.2),
    fill_mode='nearest'
)

N = 3 
for cls in ["CANCER", "NON CANCER"]:
    in_folder = os.path.join(preprocessed_folder, cls)
    out_folder = os.path.join(aug_folder, cls)
    for fname in tqdm(
        [f for f in os.listdir(in_folder) if f.lower().endswith((".jpg", ".jpeg", ".png"))],
        desc=f"Augmenting {cls}"
    ):
        src = os.path.join(in_folder, fname)
        try:
            img = tf.keras.preprocessing.image.load_img(src)
            arr = tf.keras.preprocessing.image.img_to_array(img).astype('uint8')

            orig_name = os.path.splitext(fname)[0] + "_orig.png"
            tf.keras.preprocessing.image.save_img(os.path.join(out_folder, orig_name), arr)

            x = arr.reshape((1,) + arr.shape)  # (1, H, W, C)
            it = datagen.flow(x, batch_size=1)
            for i in range(N):
                batch = next(it)
                aug_img = batch[0].astype('uint8')

                aug_img = random_contrast(aug_img).numpy()

                aug_name = os.path.splitext(fname)[0] + f"_aug{i}.png"
                tf.keras.preprocessing.image.save_img(os.path.join(out_folder, aug_name), aug_img)

        except Exception as e:
            print("Augmentation error for", src, e)

aug_counts = {
    cls: len([
        f for f in os.listdir(os.path.join(aug_folder, cls))
        if f.lower().endswith((".png", ".jpg", ".jpeg"))
    ])
    for cls in ["CANCER", "NON CANCER"]
}
print("After Augmentation (before balancing):")
for cls in aug_counts:
    print(f"  {cls}: {aug_counts[cls]} images")
print(f"  Total: {sum(aug_counts.values())}\n")
# Out:
# Before Augmentation:
#   CANCER: 1000 images
#   NON CANCER: 700 images
#   Total: 1700
# Augmenting CANCER:   0%|          | 0/1000 [00:00<?, ?it/s]I0000 00:00:1760103068.303992      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Augmenting CANCER: 100%|██████████| 1000/1000 [02:44<00:00,  6.07it/s]
# Augmenting NON CANCER: 100%|██████████| 700/700 [01:52<00:00,  6.23it/s]
# After Augmentation (before balancing):
#   CANCER: 4000 images
#   NON CANCER: 2800 images
#   Total: 6800

# %%
max_count = max(aug_counts.values())
for cls in ["CANCER", "NON CANCER"]:
    folder = os.path.join(aug_folder, cls)
    files = [f for f in os.listdir(folder) if f.lower().endswith((".png", ".jpg", ".jpeg"))]
    if len(files) == 0:
        continue
    i = 0
    while len(files) < max_count:
        f = random.choice(files)
        src = os.path.join(folder, f)
        dst = os.path.join(folder, f"copy_{i}_{f}")
        shutil.copy(src, dst)
        files.append(os.path.basename(dst))
        i += 1

final_counts = {cls: len([f for f in os.listdir(os.path.join(aug_folder, cls))
                          if f.lower().endswith((".png", ".jpg", ".jpeg"))]) for cls in ["CANCER", "NON CANCER"]}
print("After Balancing:")
for cls in final_counts:
    print(f"  {cls}: {final_counts[cls]} images")
print(f"  Total: {sum(final_counts.values())}\n")
# Out:
# After Balancing:
#   CANCER: 4000 images
#   NON CANCER: 4000 images
#   Total: 8000

# %%
split_folder = "/kaggle/working/split_dataset"
for split in ["train", "val", "test"]:
    for cls in ["CANCER", "NON CANCER"]:
        os.makedirs(os.path.join(split_folder, split, cls), exist_ok=True)

train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15 

for cls in ["CANCER", "NON CANCER"]:
    cls_path = os.path.join(aug_folder, cls)
    imgs = [f for f in os.listdir(cls_path) if f.lower().endswith((".png", ".jpg", ".jpeg"))]
    random.shuffle(imgs)
    n_total = len(imgs)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    train_imgs = imgs[:n_train]
    val_imgs = imgs[n_train:n_train+n_val]
    test_imgs = imgs[n_train+n_val:]
    for f in train_imgs:
        shutil.copy(os.path.join(cls_path, f), os.path.join(split_folder, "train", cls, f))
    for f in val_imgs:
        shutil.copy(os.path.join(cls_path, f), os.path.join(split_folder, "val", cls, f))
    for f in test_imgs:
        shutil.copy(os.path.join(cls_path, f), os.path.join(split_folder, "test", cls, f))

print("Dataset successfully split into train/val/test.")
# Out:
# Dataset successfully split into train/val/test.

# %%
BATCH_SIZE = 16
IMG_SIZE = (256, 256)

train_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(split_folder, "train"),
    labels='inferred',
    label_mode='int',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(split_folder, "val"),
    labels='inferred',
    label_mode='int',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=42
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(split_folder, "test"),
    labels='inferred',
    label_mode='int',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names
print("Classes:", class_names)

normalization = layers.Rescaling(1./255)
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.map(lambda x, y: (normalization(x), y)).cache().shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.map(lambda x, y: (normalization(x), y)).cache().prefetch(AUTOTUNE)
test_ds = test_ds.map(lambda x, y: (normalization(x), y)).cache().prefetch(AUTOTUNE)
# Out:
# Found 5600 files belonging to 2 classes.
# Found 1200 files belonging to 2 classes.
# Found 1200 files belonging to 2 classes.
# Classes: ['CANCER', 'NON CANCER']

# %%
class DropBlock2D(layers.Layer):
    def __init__(self, drop_prob=0.1, block_size=7, **kwargs):
        super(DropBlock2D, self).__init__(**kwargs)
        self.drop_prob = drop_prob
        self.block_size = block_size

    def call(self, x, training=None):
        if not training or self.drop_prob == 0.0:
            return x
        h, w = x.shape[1], x.shape[2]
        gamma = self.drop_prob * (h * w) / (self.block_size**2) / ((h - self.block_size + 1) * (w - self.block_size + 1))
        mask = tf.cast(tf.random.uniform((tf.shape(x)[0], h, w, 1)) < gamma, x.dtype)
        mask = tf.nn.max_pool2d(mask, ksize=self.block_size, strides=1, padding="SAME")
        mask = 1 - mask
        x = x * mask * (tf.cast(tf.size(mask), tf.float32) / tf.reduce_sum(mask))
        return x

def SEBlockKeras(input_tensor, reduction=8):
    channels = int(input_tensor.shape[-1])
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Dense(channels // reduction, activation='relu', use_bias=False)(se)
    se = layers.Dense(channels, activation='sigmoid', use_bias=False)(se)
    se = layers.Reshape((1, 1, channels))(se)
    x = layers.Multiply()([input_tensor, se])
    return x

def AOX_Model_Keras_Modified(input_shape=(256,256,3), num_classes=2, drop_prob=0.1):
    inputs = keras.Input(shape=input_shape)

    # Use existing data augmentation
    x = inputs

    # Conv Layers + BatchNorm + Activation
    x = layers.Conv2D(32, 3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(64, 3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(128, 3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Squeeze-Excitation Block
    x = SEBlockKeras(x, reduction=8)

    # More Conv + DropBlock + BatchNorm
    x = layers.Conv2D(128, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = DropBlock2D(drop_prob=drop_prob, block_size=5)(x)

    x = layers.Conv2D(128, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Global Depthwise Conv + Flatten
    spatial_size = x.shape[1]  # current height
    x = layers.DepthwiseConv2D(kernel_size=spatial_size, padding='valid', activation='relu')(x)
    x = layers.Flatten()(x)

    # Dropout before classifier
    x = layers.Dropout(0.4)(x)

    # Final Dense
    # outputs = layers.Dense(num_classes, activation='softmax')(x)
    outputs = layers.Dense(2, activation='softmax')(x)


    model = keras.Model(inputs, outputs, name="AOX_Model_Modified_BN")
    return model

model = AOX_Model_Keras_Modified(input_shape=(256,256,3), drop_prob=0.1)
model.summary()
keras.utils.plot_model(model, expand_nested=True, dpi=80, show_shapes=True)
# Out:
# Model: "AOX_Model_Modified_BN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │     18,496 │ re_lu[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │     73,856 │ re_lu_1[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_2[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │      2,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      2,048 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 128) │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ re_lu_2[0][0],    │
# │                     │ 128)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │    147,584 │ multiply[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop_block2d        │ (None, 32, 32,    │          0 │ re_lu_3[0][0]     │
# │ (DropBlock2D)       │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    147,584 │ drop_block2d[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 1, 1, 128) │    131,200 │ re_lu_4[0][0]     │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 128)       │          0 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2)         │        258 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 525,890 (2.01 MB)
#  Trainable params: 524,930 (2.00 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
EPOCHS = 50
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
checkpoint = keras.callbacks.ModelCheckpoint("/kaggle/working/best_aox_model.h5", save_best_only=True, monitor='val_loss')

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stopping, reduce_lr, checkpoint]
)

model.save("/kaggle/working/final_aox_model_keras.h5")
print("Model saved.")
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760103398.933397     103 service.cc:148] XLA service 0x79a0f403d510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760103398.934150     103 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1760103399.672224     103 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   7/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4936 - loss: 0.7033
# I0000 00:00:1760103404.257597     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 31s 25ms/step - accuracy: 0.6752 - loss: 0.5867 - val_accuracy: 0.6817 - val_loss: 0.5959 - learning_rate: 1.0000e-04
# Epoch 2/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8414 - loss: 0.3803 - val_accuracy: 0.8550 - val_loss: 0.3475 - learning_rate: 1.0000e-04
# Epoch 3/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8711 - loss: 0.3108 - val_accuracy: 0.8767 - val_loss: 0.2971 - learning_rate: 1.0000e-04
# Epoch 4/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8941 - loss: 0.2613 - val_accuracy: 0.8992 - val_loss: 0.2659 - learning_rate: 1.0000e-04
# Epoch 5/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9183 - loss: 0.2245 - val_accuracy: 0.8875 - val_loss: 0.2588 - learning_rate: 1.0000e-04
# Epoch 6/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9244 - loss: 0.1911 - val_accuracy: 0.9183 - val_loss: 0.2054 - learning_rate: 1.0000e-04
# Epoch 7/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9401 - loss: 0.1605 - val_accuracy: 0.9117 - val_loss: 0.2277 - learning_rate: 1.0000e-04
# Epoch 8/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9500 - loss: 0.1362 - val_accuracy: 0.8658 - val_loss: 0.3081 - learning_rate: 1.0000e-04
# Epoch 9/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9586 - loss: 0.1207 - val_accuracy: 0.9442 - val_loss: 0.1489 - learning_rate: 1.0000e-04
# Epoch 10/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9670 - loss: 0.0996 - val_accuracy: 0.9450 - val_loss: 0.1552 - learning_rate: 1.0000e-04
# Epoch 11/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9701 - loss: 0.0874 - val_accuracy: 0.9425 - val_loss: 0.1565 - learning_rate: 1.0000e-04
# Epoch 12/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9699 - loss: 0.0848 - val_accuracy: 0.9533 - val_loss: 0.1365 - learning_rate: 1.0000e-04
# Epoch 13/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9833 - loss: 0.0600 - val_accuracy: 0.9400 - val_loss: 0.1766 - learning_rate: 1.0000e-04
# Epoch 14/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9821 - loss: 0.0574 - val_accuracy: 0.9350 - val_loss: 0.2085 - learning_rate: 1.0000e-04
# Epoch 15/50
# 349/350 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9876 - loss: 0.0527
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9876 - loss: 0.0526 - val_accuracy: 0.9433 - val_loss: 0.1703 - learning_rate: 1.0000e-04
# Epoch 16/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9921 - loss: 0.0330 - val_accuracy: 0.9517 - val_loss: 0.1583 - learning_rate: 5.0000e-05
# Epoch 17/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9974 - loss: 0.0231 - val_accuracy: 0.9608 - val_loss: 0.1145 - learning_rate: 5.0000e-05
# Epoch 18/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9939 - loss: 0.0249 - val_accuracy: 0.9592 - val_loss: 0.1428 - learning_rate: 5.0000e-05
# Epoch 19/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9921 - loss: 0.0285 - val_accuracy: 0.9342 - val_loss: 0.1837 - learning_rate: 5.0000e-05
# Epoch 20/50
# 349/350 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9936 - loss: 0.0246
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9936 - loss: 0.0246 - val_accuracy: 0.9558 - val_loss: 0.1532 - learning_rate: 5.0000e-05
# Epoch 21/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9949 - loss: 0.0177 - val_accuracy: 0.9625 - val_loss: 0.1192 - learning_rate: 2.5000e-05
# Epoch 22/50
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9982 - loss: 0.0139 - val_accuracy: 0.9642 - val_loss: 0.1185 - learning_rate: 2.5000e-05
# Epoch 23/50
# 349/350 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9994 - loss: 0.0102
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9994 - loss: 0.0102 - val_accuracy: 0.9650 - val_loss: 0.1194 - learning_rate: 2.5000e-05
# Model saved.

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
import seaborn as sns

y_true = []
y_pred = []
for x_batch, y_batch in test_ds.unbatch().batch(64): 
    preds = model.predict(x_batch)
    y_true.extend(y_batch.numpy().tolist())
    y_pred.extend(np.argmax(preds, axis=1).tolist())

test_acc = accuracy_score(y_true, y_pred)
print(f"Test Accuracy: {test_acc:.4f}")

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Keras pipeline finished. Model, plots and architecture diagram saved in /kaggle/working/")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Test Accuracy: 0.9525
# Classification Report:
#               precision    recall  f1-score   support
#
#       CANCER       0.95      0.96      0.95       600
#   NON CANCER       0.96      0.95      0.95       600
#
#     accuracy                           0.95      1200
#    macro avg       0.95      0.95      0.95      1200
# weighted avg       0.95      0.95      0.95      1200
# Keras pipeline finished. Model, plots and architecture diagram saved in /kaggle/working/

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize

y_true = np.array(y_true)
y_pred_probs = []

for x_batch, _ in test_ds.unbatch().batch(64):
    probs = model.predict(x_batch)
    y_pred_probs.extend(probs)
y_pred_probs = np.array(y_pred_probs)

if y_true.ndim > 1:
    y_true_indices = np.argmax(y_true, axis=1)
else:
    y_true_indices = y_true


fpr, tpr, _ = roc_curve(y_true_indices, y_pred_probs[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# ROC AUC: 0.9908

# %%
def compute_saliency(model, img_array, class_index=None):
    img_array = tf.convert_to_tensor(img_array)

    with tf.GradientTape() as tape:
        tape.watch(img_array) 
        preds = model(img_array)
        if class_index is None:
            class_index = tf.argmax(preds[0])
        loss = preds[:, class_index]


    grads = tape.gradient(loss, img_array)
    saliency = tf.abs(grads)
    saliency = tf.reduce_max(saliency, axis=-1) 
    saliency = (saliency - tf.reduce_min(saliency)) / (tf.reduce_max(saliency) - tf.reduce_min(saliency) + 1e-8)  # normalize 0-1
    return saliency.numpy().squeeze()


N = 5 
test_images = list(test_ds.unbatch()) 
random_samples = random.sample(test_images, N)

for i, (img_tensor, label_tensor) in enumerate(random_samples):
    img_array = img_tensor[tf.newaxis, ...]  

    saliency_map = compute_saliency(model, img_array)

    img = img_tensor.numpy()  
    heatmap = plt.cm.hot(saliency_map)[..., :3] 
    superimposed_img = 0.5*img + 0.5*heatmap

    plt.figure(figsize=(5,5))
    plt.imshow(superimposed_img)
    plt.axis('off')
    plt.title(f"Image {i+1}: True={class_names[label_tensor.numpy()]}, Pred={class_names[np.argmax(model.predict(img_array))]}")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
